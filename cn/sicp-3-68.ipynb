# %% [markdown]
# ## title

# %%
(define (stream-enumerate-interval low high)
  (if (> low high)
      the-empty-stream
      (cons-stream 
       low
       (stream-enumerate-interval (+ low 1) high))))

(define integers-1-50 (stream-enumerate-interval 1 50))

(define (stream-integers-from n)
  (cons-stream n (stream-integers-from (+ n 1))))

(define integers (stream-integers-from 1))

(define (stream-for-first-n-elements proc s n)
  (define (inter-for-each proc s current-n)
    (if (stream-null? s)
	'done
	(if (> current-n n)
	    'done
	    (begin (proc (stream-car s))
		   (inter-for-each proc (stream-cdr s) (+ current-n 1))))))
  (inter-for-each proc s 1))

(define (stream-for-each proc s)
  (if (stream-null? s)
      'done
      (begin (proc (stream-car s))
	     (stream-for-each proc (stream-cdr s)))))


(define (display-stream s)
  (stream-for-each display-line s)
  (newline))

(define (display-stream-for-first-n s n)
  (stream-for-first-n-elements display-line s n)
  (newline))

(define (display-line x)
  (newline)
  (display x))


(define (interleave s1 s2)
  (if (stream-null? s1)
      s2
      (cons-stream (stream-car s1)
		   (interleave s2 (stream-cdr s1)))))

(define (pairs s t)
  (cons-stream
   (list (stream-car s) (stream-car t))
   (interleave
    (stream-map (lambda (x) (list (stream-car s) x))
		(stream-cdr t))
    (pairs (stream-cdr s) (stream-cdr t)))))

(define (full-pairs s t)
  (interleave (pairs s t) (stream-map (lambda (x) (list (cadr x) (car x))) (pairs s t))))

(define (wrong-pairs s t)
  (interleave
   (stream-map (lambda (x) (list (stream-car s) x))
	       t)
   (wrong-pairs (stream-cdr s) (stream cdr t))))


(define (improved-wrong-pairs s t n)
  (if (< n 0)
      the-empty-stream
      (interleave
       (stream-map (lambda (x) (list (stream-car s) x))
		   t)
       (improved-wrong-pairs (stream-cdr s) (stream cdr t) (- n 1)))))


(define (start-test-3-68)

  (display "it will be a infinitely loop untill maximum recrusion depth exceeded.") (newline)
  (display "try it with (wrong-pairs integers integers) if you don't beleive it.") (newline))
# Out:
# Traceback (most recent call last):
#   File "In [1]", line 8, col 23, in 'stream-enumerate-interval'
#   File "In [1]", line 6, col 8, in 'stream-enumerate-interval'
#   File "In [1]", line 6, col 8, in 'stream-enumerate-interval'
#   File "In [1]", line 6, col 8, in 'stream-enumerate-interval'
#   File "In [1]", line 6, col 8, in 'stream-enumerate-interval'
#   File "In [1]", line 6, col 8, in 'stream-enumerate-interval'
#   File "In [1]", line 6, col 8, in 'stream-enumerate-interval'
#   File "In [1]", line 6, col 8, in 'stream-enumerate-interval'
#   File "In [1]", line 6, col 8, in 'stream-enumerate-interval'
#   File "In [1]", line 6, col 8, in 'stream-enumerate-interval'
#   File "In [1]", line 6, col 8, in 'stream-enumerate-interval'
#   File "In [1]", line 6, col 8, in 'stream-enumerate-interval'
#   File "In [1]", line 6, col 8, in 'stream-enumerate-interval'
#   File "In [1]", line 6, col 8, in 'stream-enumerate-interval'
# ...
